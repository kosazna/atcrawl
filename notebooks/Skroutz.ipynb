# %%
from atcrawl import *

# %%
# url = "https://www.skroutz.gr/c/1228/Ladia-Autokinhtou/m/8410/Castrol.html?fbclid=IwAR0x_d8EpxDRRLp4HLJ5oM1nsImFUnRDl05ZKD0nCWNdr_xE1pUSH-qTMnI"
url = "https://www.skroutz.gr/c/1246/patakia_autokinitou/m/17674/Autoline/f/536464/moketa.html?o=%CF%80%CE%B1%CF%84%CE%B1%CE%BA%CE%B9%CE%B1+%CE%B1%CF%85%CF%84%CE%BF%CE%BA%CE%B9%CE%BD%CE%B7%CF%84%CE%BF%CF%85"

# %%
sk = Skroutz(url)
sk.launch('Chrome', paths.get_chrome())

# %%
sk.pre_collect()
sk.collect()
# Out:
# Η διαδικασία σταμάτησε.

# %%
_params = {'meta1': 'Η καλύτερη τιμή για',
                   'meta2': 'Τα καλύτερα',
                   'meta3': '',
                   'brand': 'autoline',
                   'discount': -25}

# %%
sk.transform(**_params)
# Out:
# C:\Users\aznavouridis.k\miniconda3\envs\dsc\lib\site-packages\atcrawl\crawlers\skroutz\crawler.py:132: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   'string').str.replace('.', ',')
# C:\Users\aznavouridis.k\miniconda3\envs\dsc\lib\site-packages\atcrawl\crawlers\skroutz\crawler.py:133: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   _data[col_name] = _data[col_name].str.replace('.', ',')

# %%
sk.filters

# %%
sk.transformed_data
# Out:
#         brand                                              title description  \
# 0    autoline             Autoline Πατάκια Μπροστινά 2τμχ Μοκέτα
# 1    autoline   Autoline Σετ Πατάκια 4τμχ Μοκέτα Classic Colours
# 2    autoline                     ΜΟΚΕΤΕΣ ΣΚΑΦΑΚΙ 4τμχ - Μπορντό
# 3    autoline              Autoline Σετ Πατάκια 5τμχ Μοκέτα Mild
# 4    autoline   Autoline Σετ Πατάκια 4τμχ Μοκέτα Classic Colours
# ..        ...                                                ...         ...
# 100  autoline                        ΣΚΑΦΑΚΙΑ ΜΟΚΕΤΕΣ ΓΚΡΙ 4 ΤΜΧ
# 101  autoline         ΠΑΤΑΚΙΑ ΜΟΚΕΤΕΣ ΜΕ ΡΕΛΙ ΜΑΥΡΑ - ΜΠΛΕ 4 ΤΜΧ
# 102  autoline  Autoline Σετ Πατάκια μοκέτες πατάκια 4τμχ Λάστ...
# 103  autoline  Autoline Σετ Πατάκια μοκέτες πατάκια 4τμχ Λάστ...
# 104  autoline  ΜΟΚΕΤΕΣ ΣΕΤ ΜΕ ΡΕΛΙ 4τμχ Χρώμα: Μαυρο/Γκρι, Κα...
#
#                                       meta_description        details  \
# 0    Η καλύτερη τιμή για Autoline Πατάκια Μπροστινά...  Υλικό: Μοκέτα
# ...
