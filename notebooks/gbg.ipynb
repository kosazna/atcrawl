# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

import requests
from bs4 import BeautifulSoup

# %%
url = "http://www.gbg-eshop.gr/demo/Authenticate3.aspx?ReturnUrl=%2fdemo%2f"

firefox_exe = "C:\\Users\\aznavouridis.k\\.atcrawl\\geckodriver.exe"

# %%
driver = webdriver.Firefox(executable_path=firefox_exe)
driver.maximize_window()
driver.get(url)

# %%
driver.find_element(By.CLASS_NAME, "GenericStyle_Link").text
# Out:
# '065606440'

# %%
for i in driver.find_elements(By.TAG_NAME, "b"):
    prices 
    try:
        link = i.find_element(By.TAG_NAME, 'a').get_attribute('href')
    except NoSuchElementException:
        prices = None

    print(i.text, link)
# Out:
# ?ItemID=132107042&kodan=132007042
# ΓΡΥΛΛΟΣ ΠΑΡΑΘ. ΕΜΠ. ΗΛΕΚΤ. (SPORTBACK/SDN) (Χ/ΜΟΤΕΡ)ΕΥΡΩΠ ΑΡ None
# 97,84€ None
# 54,21€ None
#  -  None
# 132107041 http://www.gbg-eshop.gr/demo/item.aspx?ItemID=132107041&kodan=132007041
# ΓΡΥΛΛΟΣ ΠΑΡΑΘ. ΕΜΠ. ΗΛΕΚΤ. (SPORTBACK/SDN) (Χ/ΜΟΤΕΡ)ΕΥΡΩΠ ΔΕ None
# 97,84€ None
# 54,21€ None
#  -  None
# 132107052 http://www.gbg-eshop.gr/demo/item.aspx?ItemID=132107052&kodan=132007052
# ΓΡΥΛΛΟΣ ΠΑΡΑΘ. ΠΙΣΩ ΗΛΕΚΤ.(Χ/ΜΟΤΕΡ)ΕΥΡΩΠ ΑΡ None
# 96,16€ None
# 53,32€ None
#  -  None
# 132107051 http://www.gbg-eshop.gr/demo/item.aspx?ItemID=132107051&kodan=132007051
# ΓΡΥΛΛΟΣ ΠΑΡΑΘ. ΠΙΣΩ ΗΛΕΚΤ.(Χ/ΜΟΤΕΡ)ΕΥΡΩΠ ΔΕ None
# 96,16€ None
# 53,32€ None
#  -  None
# 132107140 http://www.gbg-eshop.gr/demo/item.aspx?ItemID=132107140&kodan=132007140
# ΔΙΑΚΟΠΤΗΣ ΦΩΤΩΝ None
# 101,25€ None
# 55,90€ None
#  -  None
# 132104012 http://www.gbg-eshop.gr/demo/item.aspx?ItemID=132104012&kodan=132104012
# ΔΙΑΚΟΣΜΗΤΙΚΟ ΠΡΟΦΥΛΑΚΤΗΡΑ ΕΜΠΡΟΣ ΚΑΤΩ ΑΡ None
# 14,14€ None
# 7,79€ None
#  -  None
# ...

# %%
driver.find_element(By.XPATH, '//*[@id="divGrid"]/div[2]/table/tbody/tr[27]').find_element(By.TAG_NAME, 'a').get_attribute('href')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-44-65cb0bc852f0> in <module>
# ----> 1 driver.find_element(By.XPATH, '//*[@id="divGrid"]/div[2]/table/tbody/tr[27]').find_element(By.TAG_NAME, 'a').get_attribute('href')
#
# ~\miniconda3\envs\dsc\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\miniconda3\envs\dsc\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# ...

# %%
driver.find_element(By.XPATH, '//*[@id="divGrid"]/div[2]/table/tbody/tr[5]').find_element(By.TAG_NAME, 'a').text
# Out:
# '019408102'

# %%
len(driver.find_elements(By.XPATH, '//*[@id="divGrid"]/div[2]/table/tbody/tr'))
# Out:
# 26

# %%
driver.find_element(By.XPATH, '//*[@id="divGrid"]/div[2]/table/tbody/tr[4]/td[1]/b/a').text

# %%
driver.find_element(By.XPATH, '//*[@id="divGrid"]/div[2]/table/tbody/tr[1]').find_element(By.XPATH, '//*[@id="divGrid"]/div[2]/table/tbody/tr[1]/td[4]/table/tbody/tr[1]/td[2]').text
# Out:
# ''

# %%
driver.find_element(By.XPATH, '//*[@id="divGrid"]/div[2]/table/tbody/tr[1]/td[4]/table/tbody/tr[1]/td[2]').text
# Out:
# ''

# %%
driver.find_element(By.XPATH, '//*[@id="divGrid"]/div[2]/table/tbody/tr[1]').find_element(By.XPATH, '//*[@id="divGrid"]/div[2]/table/tbody/tr[1]/td[4]/table/tbody/tr[2]/td[2]').text
# Out:
# '30,40€'

# %%
driver.find_element(By.XPATH, '//*[@id="divGrid"]/div[2]/table/tbody/tr[5]/td[4]/table/tbody/tr[2]/td[2]').text
# Out:
# '0,10€'

# %%
driver.find_element(By.XPATH, '//*[@id="ctl00_centerPlaceHolder_labelItemID"]').text
# Out:
# '019406122'

# %%
driver.find_element(By.XPATH, '//*[@id="ctl00_centerPlaceHolder_labelItemDescription"]').text
# Out:
# 'ΑΝΤΑΝΑΚΛΑΣΤΙΚΟ ΠΙΣΩ ΠΡΟΦΥΛ. (GTA) 04- ΑΡ'

# %%
driver.find_element(By.XPATH, '//*[@id="middleFrame"]/div[2]/table/tbody/tr[4]/td[2]/div').text
# Out:
# 'ALFA ROMEO 147 00-10'

# %%
driver.find_element(By.XPATH, '//*[@id="middleFrame"]/div[2]/table/tbody/tr[6]/td[12]').text
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-36-9ee12e09bc70> in <module>
# ----> 1 driver.find_element(By.XPATH, '//*[@id="middleFrame"]/div[2]/table/tbody/tr[6]/td[12]').text
#
# ~\miniconda3\envs\dsc\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\miniconda3\envs\dsc\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
# ...

# %%
driver.find_element(By.ID, 'ctl00_centerPlaceHolder_imgPreview').get_attribute('src')
# Out:
# 'http://gbg-eshop.gr/images/Parts/0194/019406122.jpg'

# %%
r = requests.get("http://www.gbg-eshop.gr/demo/item.aspx?ItemID=065407042&kodan=065407042")
soup = BeautifulSoup(r.text, 'lxml')

# %%
soup
# Out:
# e.min.css" rel="stylesheet" type="text/css"/>
# <link href="App_Themes/Boot_theme/style.css" rel="stylesheet"/>
# <style type="text/css">
#
#         html {
#             font-size:16px;
#         }
#
#         .btn-fb {
#             color: #fff;
#             background-color: #425F9C;
#             border-color: #425F9C;
#         }
#
#             .btn-fb:hover, .btn-fb:focus, .btn-fb:active, .btn-fb.active, .open > .dropdown-toggle.btn-fb {
#                 color: white;
#                 background-color: #4C6EB5;
#                 border-color: #4C6EB5;
#             }
#
#         .floatRight {
#             float: right;
#         }
#
#
#     </style>
# ...

# %%
soup.find('img', {'id': 'ctl00_centerPlaceHolder_imgPreview'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d93c2405c498> in <module>
# ----> 1 soup.find('img', {'id': 'ctl00_centerPlaceHolder_imgPreview'}).text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
for i in a.find_elements(By.TAG_NAME, 'tr'):
    print(i.text)
# Out:
# Κωδικός Είδους   132108315
#
#
#
# Περιγραφή Είδους   ΑΜΟΡΤΙΣΕΡ ΜΠΑΓΚΑΖ CABRIO (234L-600N)
# Τεχνικά χαρακτηριστικά
# Εφαρμογές
# AUDI A3 SPORT SEDAN/CABRIO 13-16
# AUDI A3 SPORT SEDAN/CABRIO 16-
# Ομοιοι και Συναφείς Κωδικοί   (Δεν υπάρχουν)
# Γνήσιοι Κωδικοί   8V7827552A

# %%
import re

def num_from_text(text):
    """
    Finds and returns a number from a string. If number is splitted with comma
    instead of a dot the two elements will be returned

    :param text: str
        text with number
    :return: list
        list of numbers
    """
    pattern = r'[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?'
    return re.findall(pattern, text)


def fmtnumber(number: list):
    """
    Formats a list of number as a single number

    :param number: list
        list of numbers
    :return: str
        single number
    """
    if len(number) > 1:
        nums = [num.replace('.', '').replace(',', '') for num in number]
        return '.'.join(nums)
    else:
        return number[0].replace('.', '').replace(',', '')

# %%
fmtnumber(num_from_text('30,40€'))
# Out:
# '30.40'

# %%
a = [1,2,3]
a.pop(0)
a.pop(0)
a.pop(0)
a.pop(0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-02711d0855cf> in <module>
#       3 a.pop(0)
#       4 a.pop(0)
# ----> 5 a.pop(0)
#
# IndexError: pop from empty list
