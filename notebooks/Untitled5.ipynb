# %%
import pandas as pd

# %%
df = pd.read_excel('test_lastixa.xlsx')

# %%
phrase = 'Η καλύτερη τιμή σε'

# %%
phrase + ' ' + df['article_no']
# Out:
# 0      Η καλύτερη τιμή σε Autoline Πατάκια Μπροστινά ...
# 1      Η καλύτερη τιμή σε Autoline Σετ Πατάκια 4τμχ Λ...
# 2      Η καλύτερη τιμή σε Autoline Σετ Πατάκια 5τμχ Λ...
# 3      Η καλύτερη τιμή σε Autoline Σετ Πατάκια 4τμχ Λ...
# 4      Η καλύτερη τιμή σε Autoline Σετ Πατάκια 4τμχ Λ...
#                              ...
# 242    Η καλύτερη τιμή σε Σκαφάκια Πίσω - YARK / Κόκκ...
# 243    Η καλύτερη τιμή σε ΠΑΤΑΚΙΑ ΣΕΤ ΛΑΣΤΙΧΟ 4τμχ Χρ...
# 244    Η καλύτερη τιμή σε Autoline Σετ Πατάκια 4τμχ α...
# 245    Η καλύτερη τιμή σε ΠΑΤΑΚΙΑ ΛΑΣΤΙΧΟ ΑΛΟΥΜΙΝΙΟΥ ...
# 246    Η καλύτερη τιμή σε ΣΚΑΦΑΚΙΑ ΛΑΣΤΙΧΟ PACKY PODA...
# Name: article_no, Length: 247, dtype: object

# %%
df['test'] = 'sdf'

# %%
df
# Out:
#                                             img_source  \
# 0    https://b.scdn.gr/images/sku_main_images/01452...
# 1    https://b.scdn.gr/images/sku_main_images/01473...
# 2    https://c.scdn.gr/images/sku_main_images/01871...
# 3    https://a.scdn.gr/images/sku_main_images/01703...
# 4    https://d.scdn.gr/images/sku_main_images/02112...
# ..                                                 ...
# 242  https://d.scdn.gr/images/sku_main_images/02130...
# 243  https://d.scdn.gr/images/sku_main_images/02517...
# 244  https://b.scdn.gr/images/sku_main_images/02660...
# 245  https://c.scdn.gr/images/sku_main_images/02629...
# 246  https://b.scdn.gr/images/sku_main_images/02624...
#
#                                             article_no retail_price  \
# 0         Autoline Πατάκια Μπροστινά 2τμχ Λάστιχο Abba         9,09
# 1               Autoline Σετ Πατάκια 4τμχ Λάστιχο Abba        12,50
# 2              Autoline Σετ Πατάκια 5τμχ Λάστιχο Promo        14,80
# ...
